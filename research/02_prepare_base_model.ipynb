# %%
import os
os.chdir("../")

# %%
from dataclasses import dataclass
from pathlib import Path

# %%
from src.bone_classifier import log
from src.bone_classifier.constants import *
from src.bone_classifier.utils.common import read_yaml, create_directories

# %%
@dataclass(frozen=True)
class PrepareBaseModelConfig: 
    root_dir: Path
    base_model_path: Path
    updated_base_model_path: Path

    params_image_size: list
    params_include_top: bool
    params_weight : str
    params_classes: int
    params_learning_rate: int

# %%
class ConfigurationManager:
    def __init__(self, config_filepath=CONFIG_FILE_PATH, 
                 params_filepath=PARAMS_FILE_PATH):
        self.config=read_yaml(config_filepath)
        self.params=read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_prepare_base_model(self)-> PrepareBaseModelConfig:
        config=self.config.prepare_base_model
        create_directories([config.root_dir])
        
        prepare_base_model=PrepareBaseModelConfig(
            root_dir=Path(config.root_dir), 
            base_model_path=Path(config.base_model_path),
            updated_base_model_path=Path(config.updated_model_path),

            params_image_size=self.params.IMAGE_SIZE,
            params_include_top=self.params.INCLUDE_TOP,
            params_weight=self.params.WEIGHTS,
            params_classes=self.params.CLASSES,
            params_learning_rate=self.params.LEARNING_RATE
            )
        return prepare_base_model

# %%
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.layers import BatchNormalization

# %%
class PreparBaseModel: 
    def __init__(self, config: PrepareBaseModelConfig) -> None:
        self.config=config

    @staticmethod
    def save_model(path: Path, model: keras.Model):
        model.save(path)
        log.info(f"Base model save sucessfully at path: {path}")
        

    def get_base_model(self):
        self.model=InceptionV3(
            include_top=self.config.params_include_top,
            weights=self.config.params_weight,
            input_shape=self.config.params_image_size,
            classes=self.config.params_classes)
        
        self.save_model(path=self.config.base_model_path, model=self.model)

    
    def prepare_full_model(self,freez_all, model, freez_till: int ,classes):

        if freez_all:
            for layer in model.layers: 
                model.trainable=False
            log.info(f"Model freez all")

        elif (freez_till is None) and (freez_till>0):
            for layer in model.layers[:-freez_till]:
                model.trainable=False
            log.info(f"Model freetill {freez_till}")


        flatten_in=keras.layers.Flatten()(model.output)
        x=keras.layers.Dense(1000, activation='relu')(flatten_in)
        x=keras.layers.Dropout(0.2)(x)
        x=keras.layers.BatchNormalization()(x)
        x=keras.layers.Dense(500, activation='relu')(x)
        x=keras.layers.Dense(300, activation='relu')(x)
        x=keras.layers.BatchNormalization()(x)
        prediction=keras.layers.Dense(units=5, activation='softmax')(x)

        full_model=keras.models.Model(
            inputs=model.input,
            outputs=prediction
        )

        # full_model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.01), loss=keras.losses.CategoricalCrossentropy, metrics=['acc'])
    

        full_model.summary()

        

        return full_model
    
    def update_base_model(self):
        self.full_model=self.prepare_full_model(freez_all=True, 
                                                model=self.model, 
                                                freez_till=None,
                                                classes=self.config.params_classes)
        
        self.save_model(path=self.config.updated_base_model_path, model=self.full_model)

# %%
try: 
    config=ConfigurationManager()
    preparemodel_config=config.get_prepare_base_model()
    prepare_model=PreparBaseModel(preparemodel_config)
    prepare_model.get_base_model()
    prepare_model.update_base_model()
except Exception as e: 
    raise e
# Out:
# [2024-03-15 04:14:37,297 : INFO : common : yaml file : config/config.yaml loaded sucessfully]
# [2024-03-15 04:14:37,300 : INFO : common : yaml file : params.yaml loaded sucessfully]
# [2024-03-15 04:14:37,300 : INFO : common : Created directories at : artifacts]
# [2024-03-15 04:14:37,301 : INFO : common : Created directories at : artifacts/prepare_base_model]
# [2024-03-15 04:14:37,944 : WARNING : saving_utils : Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.]
# [2024-03-15 04:14:38,031 : INFO : 4172541680 : Base model save sucessfully at path: artifacts/prepare_base_model/model.h5]
# [2024-03-15 04:14:38,838 : INFO : 4172541680 : Model freez all]
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_26 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_2350 (Conv2D)        (None, 111, 111, 32)         864       ['input_26[0][0]']
#
#  batch_normalization_2370 (  (None, 111, 111, 32)         96        ['conv2d_2350[0][0]']
#  BatchNormalization)
#
#  activation_2350 (Activatio  (None, 111, 111, 32)         0         ['batch_normalization_2370[0][
#  n)                                                                 0]']
#
#  conv2d_2351 (Conv2D)        (None, 109, 109, 32)         9216      ['activation_2350[0][0]']
#
#  batch_normalization_2371 (  (None, 109, 109, 32)         96        ['conv2d_2351[0][0]']
#  BatchNormalization)
#
#  activation_2351 (Activatio  (None, 109, 109, 32)         0         ['batch_normalization_2371[0][
#  n)                                                                 0]']
#
#  conv2d_2352 (Conv2D)        (None, 109, 109, 64)         18432     ['activation_2351[0][0]']
#
#  batch_normalization_2372 (  (None, 109, 109, 64)         192       ['conv2d_2352[0][0]']
#  BatchNormalization)
#
#  activation_2352 (Activatio  (None, 109, 109, 64)         0         ['batch_normalization_2372[0][
#  n)                                                                 0]']
#
#  max_pooling2d_100 (MaxPool  (None, 54, 54, 64)           0         ['activation_2352[0][0]']
#  ing2D)
#
#  conv2d_2353 (Conv2D)        (None, 54, 54, 80)           5120      ['max_pooling2d_100[0][0]']
#
#  batch_normalization_2373 (  (None, 54, 54, 80)           240       ['conv2d_2353[0][0]']
#  BatchNormalization)
#
#  activation_2353 (Activatio  (None, 54, 54, 80)           0         ['batch_normalization_2373[0][
#  n)                                                                 0]']
#
#  conv2d_2354 (Conv2D)        (None, 52, 52, 192)          138240    ['activation_2353[0][0]']
#
#  batch_normalization_2374 (  (None, 52, 52, 192)          576       ['conv2d_2354[0][0]']
#  BatchNormalization)
#
#  activation_2354 (Activatio  (None, 52, 52, 192)          0         ['batch_normalization_2374[0][
#  n)                                                                 0]']
#
#  max_pooling2d_101 (MaxPool  (None, 25, 25, 192)          0         ['activation_2354[0][0]']
#  ing2D)
#
#  conv2d_2358 (Conv2D)        (None, 25, 25, 64)           12288     ['max_pooling2d_101[0][0]']
#
#  batch_normalization_2378 (  (None, 25, 25, 64)           192       ['conv2d_2358[0][0]']
#  BatchNormalization)
#
#  activation_2358 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2378[0][
#  n)                                                                 0]']
#
#  conv2d_2356 (Conv2D)        (None, 25, 25, 48)           9216      ['max_pooling2d_101[0][0]']
#
#  conv2d_2359 (Conv2D)        (None, 25, 25, 96)           55296     ['activation_2358[0][0]']
#
#  batch_normalization_2376 (  (None, 25, 25, 48)           144       ['conv2d_2356[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2379 (  (None, 25, 25, 96)           288       ['conv2d_2359[0][0]']
#  BatchNormalization)
#
#  activation_2356 (Activatio  (None, 25, 25, 48)           0         ['batch_normalization_2376[0][
#  n)                                                                 0]']
#
#  activation_2359 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_2379[0][
#  n)                                                                 0]']
#
#  average_pooling2d_225 (Ave  (None, 25, 25, 192)          0         ['max_pooling2d_101[0][0]']
#  ragePooling2D)
#
#  conv2d_2355 (Conv2D)        (None, 25, 25, 64)           12288     ['max_pooling2d_101[0][0]']
#
#  conv2d_2357 (Conv2D)        (None, 25, 25, 64)           76800     ['activation_2356[0][0]']
#
#  conv2d_2360 (Conv2D)        (None, 25, 25, 96)           82944     ['activation_2359[0][0]']
#
#  conv2d_2361 (Conv2D)        (None, 25, 25, 32)           6144      ['average_pooling2d_225[0][0]'
#                                                                     ]
#
#  batch_normalization_2375 (  (None, 25, 25, 64)           192       ['conv2d_2355[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2377 (  (None, 25, 25, 64)           192       ['conv2d_2357[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2380 (  (None, 25, 25, 96)           288       ['conv2d_2360[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2381 (  (None, 25, 25, 32)           96        ['conv2d_2361[0][0]']
#  BatchNormalization)
#
#  activation_2355 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2375[0][
#  n)                                                                 0]']
#
#  activation_2357 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2377[0][
#  n)                                                                 0]']
#
#  activation_2360 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_2380[0][
#  n)                                                                 0]']
#
#  activation_2361 (Activatio  (None, 25, 25, 32)           0         ['batch_normalization_2381[0][
#  n)                                                                 0]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_2355[0][0]',
#                                                                      'activation_2357[0][0]',
#                                                                      'activation_2360[0][0]',
#                                                                      'activation_2361[0][0]']
#
#  conv2d_2365 (Conv2D)        (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_2385 (  (None, 25, 25, 64)           192       ['conv2d_2365[0][0]']
#  BatchNormalization)
#
#  activation_2365 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2385[0][
#  n)                                                                 0]']
#
#  conv2d_2363 (Conv2D)        (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_2366 (Conv2D)        (None, 25, 25, 96)           55296     ['activation_2365[0][0]']
#
#  batch_normalization_2383 (  (None, 25, 25, 48)           144       ['conv2d_2363[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2386 (  (None, 25, 25, 96)           288       ['conv2d_2366[0][0]']
#  BatchNormalization)
#
#  activation_2363 (Activatio  (None, 25, 25, 48)           0         ['batch_normalization_2383[0][
#  n)                                                                 0]']
#
#  activation_2366 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_2386[0][
#  n)                                                                 0]']
#
#  average_pooling2d_226 (Ave  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  ragePooling2D)
#
#  conv2d_2362 (Conv2D)        (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_2364 (Conv2D)        (None, 25, 25, 64)           76800     ['activation_2363[0][0]']
#
#  conv2d_2367 (Conv2D)        (None, 25, 25, 96)           82944     ['activation_2366[0][0]']
#
#  conv2d_2368 (Conv2D)        (None, 25, 25, 64)           16384     ['average_pooling2d_226[0][0]'
#                                                                     ]
#
#  batch_normalization_2382 (  (None, 25, 25, 64)           192       ['conv2d_2362[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2384 (  (None, 25, 25, 64)           192       ['conv2d_2364[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2387 (  (None, 25, 25, 96)           288       ['conv2d_2367[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2388 (  (None, 25, 25, 64)           192       ['conv2d_2368[0][0]']
#  BatchNormalization)
#
#  activation_2362 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2382[0][
#  n)                                                                 0]']
#
#  activation_2364 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2384[0][
#  n)                                                                 0]']
#
#  activation_2367 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_2387[0][
#  n)                                                                 0]']
#
#  activation_2368 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2388[0][
#  n)                                                                 0]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_2362[0][0]',
#                                                                      'activation_2364[0][0]',
#                                                                      'activation_2367[0][0]',
#                                                                      'activation_2368[0][0]']
#
#  conv2d_2372 (Conv2D)        (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_2392 (  (None, 25, 25, 64)           192       ['conv2d_2372[0][0]']
#  BatchNormalization)
#
#  activation_2372 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2392[0][
#  n)                                                                 0]']
#
#  conv2d_2370 (Conv2D)        (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_2373 (Conv2D)        (None, 25, 25, 96)           55296     ['activation_2372[0][0]']
#
#  batch_normalization_2390 (  (None, 25, 25, 48)           144       ['conv2d_2370[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2393 (  (None, 25, 25, 96)           288       ['conv2d_2373[0][0]']
#  BatchNormalization)
#
#  activation_2370 (Activatio  (None, 25, 25, 48)           0         ['batch_normalization_2390[0][
#  n)                                                                 0]']
#
#  activation_2373 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_2393[0][
#  n)                                                                 0]']
#
#  average_pooling2d_227 (Ave  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  ragePooling2D)
#
#  conv2d_2369 (Conv2D)        (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_2371 (Conv2D)        (None, 25, 25, 64)           76800     ['activation_2370[0][0]']
#
#  conv2d_2374 (Conv2D)        (None, 25, 25, 96)           82944     ['activation_2373[0][0]']
#
#  conv2d_2375 (Conv2D)        (None, 25, 25, 64)           18432     ['average_pooling2d_227[0][0]'
#                                                                     ]
#
#  batch_normalization_2389 (  (None, 25, 25, 64)           192       ['conv2d_2369[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2391 (  (None, 25, 25, 64)           192       ['conv2d_2371[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2394 (  (None, 25, 25, 96)           288       ['conv2d_2374[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2395 (  (None, 25, 25, 64)           192       ['conv2d_2375[0][0]']
#  BatchNormalization)
#
#  activation_2369 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2389[0][
#  n)                                                                 0]']
#
#  activation_2371 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2391[0][
#  n)                                                                 0]']
#
#  activation_2374 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_2394[0][
#  n)                                                                 0]']
#
#  activation_2375 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2395[0][
#  n)                                                                 0]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_2369[0][0]',
#                                                                      'activation_2371[0][0]',
#                                                                      'activation_2374[0][0]',
#                                                                      'activation_2375[0][0]']
#
#  conv2d_2377 (Conv2D)        (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_2397 (  (None, 25, 25, 64)           192       ['conv2d_2377[0][0]']
#  BatchNormalization)
#
#  activation_2377 (Activatio  (None, 25, 25, 64)           0         ['batch_normalization_2397[0][
#  n)                                                                 0]']
#
#  conv2d_2378 (Conv2D)        (None, 25, 25, 96)           55296     ['activation_2377[0][0]']
#
#  batch_normalization_2398 (  (None, 25, 25, 96)           288       ['conv2d_2378[0][0]']
#  BatchNormalization)
#
#  activation_2378 (Activatio  (None, 25, 25, 96)           0         ['batch_normalization_2398[0][
#  n)                                                                 0]']
#
#  conv2d_2376 (Conv2D)        (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_2379 (Conv2D)        (None, 12, 12, 96)           82944     ['activation_2378[0][0]']
#
#  batch_normalization_2396 (  (None, 12, 12, 384)          1152      ['conv2d_2376[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2399 (  (None, 12, 12, 96)           288       ['conv2d_2379[0][0]']
#  BatchNormalization)
#
#  activation_2376 (Activatio  (None, 12, 12, 384)          0         ['batch_normalization_2396[0][
#  n)                                                                 0]']
#
#  activation_2379 (Activatio  (None, 12, 12, 96)           0         ['batch_normalization_2399[0][
#  n)                                                                 0]']
#
#  max_pooling2d_102 (MaxPool  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  ing2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_2376[0][0]',
#                                                                      'activation_2379[0][0]',
#                                                                      'max_pooling2d_102[0][0]']
#
#  conv2d_2384 (Conv2D)        (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_2404 (  (None, 12, 12, 128)          384       ['conv2d_2384[0][0]']
#  BatchNormalization)
#
#  activation_2384 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_2404[0][
#  n)                                                                 0]']
#
#  conv2d_2385 (Conv2D)        (None, 12, 12, 128)          114688    ['activation_2384[0][0]']
#
#  batch_normalization_2405 (  (None, 12, 12, 128)          384       ['conv2d_2385[0][0]']
#  BatchNormalization)
#
#  activation_2385 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_2405[0][
#  n)                                                                 0]']
#
#  conv2d_2381 (Conv2D)        (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_2386 (Conv2D)        (None, 12, 12, 128)          114688    ['activation_2385[0][0]']
#
#  batch_normalization_2401 (  (None, 12, 12, 128)          384       ['conv2d_2381[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2406 (  (None, 12, 12, 128)          384       ['conv2d_2386[0][0]']
#  BatchNormalization)
#
#  activation_2381 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_2401[0][
#  n)                                                                 0]']
#
#  activation_2386 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_2406[0][
#  n)                                                                 0]']
#
#  conv2d_2382 (Conv2D)        (None, 12, 12, 128)          114688    ['activation_2381[0][0]']
#
#  conv2d_2387 (Conv2D)        (None, 12, 12, 128)          114688    ['activation_2386[0][0]']
#
#  batch_normalization_2402 (  (None, 12, 12, 128)          384       ['conv2d_2382[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2407 (  (None, 12, 12, 128)          384       ['conv2d_2387[0][0]']
#  BatchNormalization)
#
#  activation_2382 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_2402[0][
#  n)                                                                 0]']
#
#  activation_2387 (Activatio  (None, 12, 12, 128)          0         ['batch_normalization_2407[0][
#  n)                                                                 0]']
#
#  average_pooling2d_228 (Ave  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  ragePooling2D)
#
#  conv2d_2380 (Conv2D)        (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_2383 (Conv2D)        (None, 12, 12, 192)          172032    ['activation_2382[0][0]']
#
#  conv2d_2388 (Conv2D)        (None, 12, 12, 192)          172032    ['activation_2387[0][0]']
#
#  conv2d_2389 (Conv2D)        (None, 12, 12, 192)          147456    ['average_pooling2d_228[0][0]'
#                                                                     ]
#
#  batch_normalization_2400 (  (None, 12, 12, 192)          576       ['conv2d_2380[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2403 (  (None, 12, 12, 192)          576       ['conv2d_2383[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2408 (  (None, 12, 12, 192)          576       ['conv2d_2388[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2409 (  (None, 12, 12, 192)          576       ['conv2d_2389[0][0]']
#  BatchNormalization)
#
#  activation_2380 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_2400[0][
#  n)                                                                 0]']
#
#  activation_2383 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_2403[0][
#  n)                                                                 0]']
#
#  activation_2388 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_2408[0][
#  n)                                                                 0]']
#
#  activation_2389 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_2409[0][
#  n)                                                                 0]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_2380[0][0]',
#                                                                      'activation_2383[0][0]',
#                                                                      'activation_2388[0][0]',
#                                                                      'activation_2389[0][0]']
#
#  conv2d_2394 (Conv2D)        (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_2414 (  (None, 12, 12, 160)          480       ['conv2d_2394[0][0]']
#  BatchNormalization)
#
#  activation_2394 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_2414[0][
#  n)                                                                 0]']
#
#  conv2d_2395 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_2394[0][0]']
#
#  batch_normalization_2415 (  (None, 12, 12, 160)          480       ['conv2d_2395[0][0]']
#  BatchNormalization)
#
#  activation_2395 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_2415[0][
#  n)                                                                 0]']
#
#  conv2d_2391 (Conv2D)        (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_2396 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_2395[0][0]']
#
#  batch_normalization_2411 (  (None, 12, 12, 160)          480       ['conv2d_2391[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2416 (  (None, 12, 12, 160)          480       ['conv2d_2396[0][0]']
#  BatchNormalization)
#
#  activation_2391 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_2411[0][
#  n)                                                                 0]']
#
#  activation_2396 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_2416[0][
#  n)                                                                 0]']
#
#  conv2d_2392 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_2391[0][0]']
#
#  conv2d_2397 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_2396[0][0]']
#
#  batch_normalization_2412 (  (None, 12, 12, 160)          480       ['conv2d_2392[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2417 (  (None, 12, 12, 160)          480       ['conv2d_2397[0][0]']
#  BatchNormalization)
#
#  activation_2392 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_2412[0][
#  n)                                                                 0]']
#
#  activation_2397 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_2417[0][
#  n)                                                                 0]']
#
#  average_pooling2d_229 (Ave  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  ragePooling2D)
#
#  conv2d_2390 (Conv2D)        (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_2393 (Conv2D)        (None, 12, 12, 192)          215040    ['activation_2392[0][0]']
#
#  conv2d_2398 (Conv2D)        (None, 12, 12, 192)          215040    ['activation_2397[0][0]']
#
#  conv2d_2399 (Conv2D)        (None, 12, 12, 192)          147456    ['average_pooling2d_229[0][0]'
#                                                                     ]
#
#  batch_normalization_2410 (  (None, 12, 12, 192)          576       ['conv2d_2390[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2413 (  (None, 12, 12, 192)          576       ['conv2d_2393[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2418 (  (None, 12, 12, 192)          576       ['conv2d_2398[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2419 (  (None, 12, 12, 192)          576       ['conv2d_2399[0][0]']
#  BatchNormalization)
#
#  activation_2390 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_2410[0][
#  n)                                                                 0]']
#
#  activation_2393 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_2413[0][
#  n)                                                                 0]']
#
#  activation_2398 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_2418[0][
#  n)                                                                 0]']
#
#  activation_2399 (Activatio  (None, 12, 12, 192)          0         ['batch_normalization_2419[0][
#  n)                                                                 0]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_2390[0][0]',
#                                                                      'activation_2393[0][0]',
#                                                                      'activation_2398[0][0]',
#                                                                      'activation_2399[0][0]']
#
#  conv2d_2404 (Conv2D)        (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_2424 (  (None, 12, 12, 160)          480       ['conv2d_2404[0][0]']
#  BatchNormalization)
#
#  activation_2404 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_2424[0][
#  n)                                                                 0]']
#
#  conv2d_2405 (Conv2D)        (None, 12, 12, 160)          179200    ['activation_2404[0][0]']
#
#  batch_normalization_2425 (  (None, 12, 12, 160)          480       ['conv2d_2405[0][0]']
#  BatchNormalization)
#
#  activation_2405 (Activatio  (None, 12, 12, 160)          0         ['batch_normalization_2425[0][
# ...
#  batch_normalization_2449 (  (None, 5, 5, 384)            1152      ['conv2d_2429[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2452 (  (None, 5, 5, 384)            1152      ['conv2d_2432[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2453 (  (None, 5, 5, 384)            1152      ['conv2d_2433[0][0]']
#  BatchNormalization)
#
#  conv2d_2434 (Conv2D)        (None, 5, 5, 192)            245760    ['average_pooling2d_232[0][0]'
#                                                                     ]
#
#  batch_normalization_2446 (  (None, 5, 5, 320)            960       ['conv2d_2426[0][0]']
#  BatchNormalization)
#
#  activation_2428 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2448[0][
#  n)                                                                 0]']
#
#  activation_2429 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2449[0][
#  n)                                                                 0]']
#
#  activation_2432 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2452[0][
#  n)                                                                 0]']
#
#  activation_2433 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2453[0][
#  n)                                                                 0]']
#
#  batch_normalization_2454 (  (None, 5, 5, 192)            576       ['conv2d_2434[0][0]']
#  BatchNormalization)
#
#  activation_2426 (Activatio  (None, 5, 5, 320)            0         ['batch_normalization_2446[0][
#  n)                                                                 0]']
#
#  mixed9_0 (Concatenate)      (None, 5, 5, 768)            0         ['activation_2428[0][0]',
#                                                                      'activation_2429[0][0]']
#
#  concatenate_50 (Concatenat  (None, 5, 5, 768)            0         ['activation_2432[0][0]',
#  e)                                                                  'activation_2433[0][0]']
#
#  activation_2434 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_2454[0][
#  n)                                                                 0]']
#
#  mixed9 (Concatenate)        (None, 5, 5, 2048)           0         ['activation_2426[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_50[0][0]',
#                                                                      'activation_2434[0][0]']
#
#  conv2d_2439 (Conv2D)        (None, 5, 5, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_2459 (  (None, 5, 5, 448)            1344      ['conv2d_2439[0][0]']
#  BatchNormalization)
#
#  activation_2439 (Activatio  (None, 5, 5, 448)            0         ['batch_normalization_2459[0][
#  n)                                                                 0]']
#
#  conv2d_2436 (Conv2D)        (None, 5, 5, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_2440 (Conv2D)        (None, 5, 5, 384)            1548288   ['activation_2439[0][0]']
#
#  batch_normalization_2456 (  (None, 5, 5, 384)            1152      ['conv2d_2436[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2460 (  (None, 5, 5, 384)            1152      ['conv2d_2440[0][0]']
#  BatchNormalization)
#
#  activation_2436 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2456[0][
#  n)                                                                 0]']
#
#  activation_2440 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2460[0][
#  n)                                                                 0]']
#
#  conv2d_2437 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_2436[0][0]']
#
#  conv2d_2438 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_2436[0][0]']
#
#  conv2d_2441 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_2440[0][0]']
#
#  conv2d_2442 (Conv2D)        (None, 5, 5, 384)            442368    ['activation_2440[0][0]']
#
#  average_pooling2d_233 (Ave  (None, 5, 5, 2048)           0         ['mixed9[0][0]']
#  ragePooling2D)
#
#  conv2d_2435 (Conv2D)        (None, 5, 5, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_2457 (  (None, 5, 5, 384)            1152      ['conv2d_2437[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2458 (  (None, 5, 5, 384)            1152      ['conv2d_2438[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2461 (  (None, 5, 5, 384)            1152      ['conv2d_2441[0][0]']
#  BatchNormalization)
#
#  batch_normalization_2462 (  (None, 5, 5, 384)            1152      ['conv2d_2442[0][0]']
#  BatchNormalization)
#
#  conv2d_2443 (Conv2D)        (None, 5, 5, 192)            393216    ['average_pooling2d_233[0][0]'
#                                                                     ]
#
#  batch_normalization_2455 (  (None, 5, 5, 320)            960       ['conv2d_2435[0][0]']
#  BatchNormalization)
#
#  activation_2437 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2457[0][
#  n)                                                                 0]']
#
#  activation_2438 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2458[0][
#  n)                                                                 0]']
#
#  activation_2441 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2461[0][
#  n)                                                                 0]']
#
#  activation_2442 (Activatio  (None, 5, 5, 384)            0         ['batch_normalization_2462[0][
#  n)                                                                 0]']
#
#  batch_normalization_2463 (  (None, 5, 5, 192)            576       ['conv2d_2443[0][0]']
#  BatchNormalization)
#
#  activation_2435 (Activatio  (None, 5, 5, 320)            0         ['batch_normalization_2455[0][
#  n)                                                                 0]']
#
#  mixed9_1 (Concatenate)      (None, 5, 5, 768)            0         ['activation_2437[0][0]',
#                                                                      'activation_2438[0][0]']
#
#  concatenate_51 (Concatenat  (None, 5, 5, 768)            0         ['activation_2441[0][0]',
#  e)                                                                  'activation_2442[0][0]']
#
#  activation_2443 (Activatio  (None, 5, 5, 192)            0         ['batch_normalization_2463[0][
#  n)                                                                 0]']
#
#  mixed10 (Concatenate)       (None, 5, 5, 2048)           0         ['activation_2435[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_51[0][0]',
#                                                                      'activation_2443[0][0]']
#
#  flatten_24 (Flatten)        (None, 51200)                0         ['mixed10[0][0]']
#
#  dense_53 (Dense)            (None, 1000)                 5120100   ['flatten_24[0][0]']
#                                                           0
#
#  dropout_17 (Dropout)        (None, 1000)                 0         ['dense_53[0][0]']
#
#  batch_normalization_2464 (  (None, 1000)                 4000      ['dropout_17[0][0]']
#  BatchNormalization)
#
#  dense_54 (Dense)            (None, 500)                  500500    ['batch_normalization_2464[0][
#                                                                     0]']
#
#  dense_55 (Dense)            (None, 300)                  150300    ['dense_54[0][0]']
#
#  batch_normalization_2465 (  (None, 300)                  1200      ['dense_55[0][0]']
#  BatchNormalization)
#
#  dense_56 (Dense)            (None, 5)                    1505      ['batch_normalization_2465[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 73661289 (281.00 MB)
# Trainable params: 51855905 (197.81 MB)
# Non-trainable params: 21805384 (83.18 MB)
# __________________________________________________________________________________________________
# [2024-03-15 04:14:39,145 : WARNING : saving_utils : Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.]
# [2024-03-15 04:14:39,406 : INFO : 4172541680 : Base model save sucessfully at path: artifacts/prepare_base_model/update_model.h5]
